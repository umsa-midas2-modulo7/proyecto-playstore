# %% [markdown]
# # PRUEBA DE CLEAN

# %%
import pandas as pd
import numpy as np

# %%
 # Cargar datos
df = pd.read_csv("../data/restore/comentarios_app.csv", encoding="utf-8")
print("\n Cantidad de registros: ", len(df))
df.head()
# Out:
#  Cantidad de registros:  3000
#                                reviewId                    userName  \
# 0  cd9d5058-35c7-4072-b872-b7b927834b81            Gabriel Saavedra
# 1  9b6bb73b-6f27-4b51-a199-2be736c33d21         Ariceli Mercie Vaca
# 2  7937ccb6-bc61-42da-8e1a-1619dad7da7f            Lucia Rojas Rios
# 3  c4af1404-a063-4b36-8634-918b08f6ca2c         Royer Moye corrales
# 4  86d01eec-abe5-4f3f-8cc5-fcd4b39b4f52  Jose Dario Quisbert Flores
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Sería bueno que al recibir un pago QR se notif...      3              0
# 1                                          muy lenta      3              0
# 2                                       es muy buena      5              0
# 3                          Buena aplicación me gusta      5              0
# 4                   muy lento para aser tranferencia      2              0
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion
# 0                1.1.3  2025-09-26 14:23:53          NaN       NaN      1.1.3
# 1                1.1.3  2025-09-26 12:30:27          NaN       NaN      1.1.3
# 2                1.1.3  2025-09-26 10:11:41          NaN       NaN      1.1.3
# 3                1.1.3  2025-09-25 15:37:00          NaN       NaN      1.1.3
# 4                1.1.3  2025-09-25 14:32:51          NaN       NaN      1.1.3

# %%
# Mostrar resumen de datos faltantes
faltantes = df.isnull().sum().sort_values(ascending=False)
total = len(df)

print("Cantidad de valores faltantes por columna:")
print(faltantes)

# Mostrar también en porcentaje
print("\n Porcentaje de valores faltantes por columna:")
print((faltantes / total * 100).round(2))
# Out:
# Cantidad de valores faltantes por columna:
# repliedAt               2228
# replyContent            2228
# reviewCreatedVersion     553
# appVersion               553
# userImage                  0
# reviewId                   0
# userName                   0
# thumbsUpCount              0
# score                      0
# content                    0
# at                         0
# dtype: int64
#
#  Porcentaje de valores faltantes por columna:
# repliedAt               74.27
# replyContent            74.27
# reviewCreatedVersion    18.43
# appVersion              18.43
# userImage                0.00
# reviewId                 0.00
# userName                 0.00
# thumbsUpCount            0.00
# score                    0.00
# content                  0.00
# at                       0.00
# dtype: float64
